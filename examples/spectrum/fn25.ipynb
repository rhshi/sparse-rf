# %%
from examples.util.getDataset import getDataset
from examples.util.plotting import plot_w
from examples.util.fns import *
from examples.util.testing import shrimp_v_random, growth
from examples.util.metrics import shrimp_test, make_l2_loss
from sparse_rf.util import *
from sparse_rf.modules import make_A, make_W
from sparse_rf.algs import shrimp, l2, l1, sindy
from functools import partial
import matplotlib.pyplot as plt
from math import ceil

# %%
fn = fn25
q = 2
d = 10
m = 200
N = 1000
l = 1e-13

Xtr, Xte, Ytr, Yte = getDataset(fn, d=d, m=m)

trials = 10

# %% [markdown]
# ## $1/q$ variance

# %%
svr_q = shrimp_v_random(trials, Xtr, Ytr, Xte, Yte, q, N, l)

# %%
print("Min l2: {}".format(svr_q.err_l2))
print("SHRIMP: {}".format(svr_q.err_shrimp))
print("Random pruning: {}".format(svr_q.err_r))
# Out:
# Min l2: 0.030971460896260045
# SHRIMP: 2.6043037848399267e-07
# Random pruning: 0.037367859618385506

# %%
plt.figure(figsize=(15, 10))
plt.plot(svr_q.lengths, svr_q.train_mse_s, label="SHRIMP train mses", color="blue")
plt.plot(svr_q.lengths, svr_q.val_mse_s, label="SHRIMP val mses", color="red")
plt.plot(svr_q.lengths, svr_q.train_mse_r, label="random train mses", color="cyan")
plt.plot(svr_q.lengths, svr_q.val_mse_r, label="random val mses", color="magenta")
plt.vlines(m*0.7*0.9, 0, max(max(svr_q.train_mse_s), max(svr_q.val_mse_s), max(svr_q.train_mse_r), max(svr_q.val_mse_r)), linestyles="dotted", colors="black", label="interpolation boundary")
plt.vlines(svr_q.n_best_s, 0, max(max(svr_q.train_mse_s), max(svr_q.val_mse_s), max(svr_q.train_mse_r), max(svr_q.val_mse_r)), linestyles="dashed", colors="purple", label="SHRIMP best model")
plt.vlines(svr_q.n_best_r, 0, max(max(svr_q.train_mse_s), max(svr_q.val_mse_s), max(svr_q.train_mse_r), max(svr_q.val_mse_r)), linestyles="dashed", colors="orange", label="random best model")
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.semilogy(svr_q.lengths[:], svr_q.eigs_s_min[:], label="SHRIMP min eig", color="blue")
plt.semilogy(svr_q.lengths[:], svr_q.eigs_r_min[:], label="random min eig", color="orange")
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(svr_q.lengths, svr_q.eigs_s_max, label="SHRIMP max eig", color="blue")
plt.plot(svr_q.lengths, svr_q.eigs_r_max, label="random max eig", color="orange")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## 1000 variance

# %%
svr_q = shrimp_v_random(trials, Xtr, Ytr, Xte, Yte, q, N, l, scale=np.sqrt(1000))

# %%
print("Min l2: {}".format(svr_q.err_l2))
print("SHRIMP: {}".format(svr_q.err_shrimp))
print("Random pruning: {}".format(svr_q.err_r))
# Out:
# Min l2: 1.3417518788215665
# SHRIMP: 1.6187629295076824
# Random pruning: 1.5889599982194815

# %%
plt.figure(figsize=(15, 10))
plt.plot(svr_q.lengths, svr_q.train_mse_s, label="SHRIMP train mses", color="blue")
plt.plot(svr_q.lengths, svr_q.val_mse_s, label="SHRIMP val mses", color="red")
plt.plot(svr_q.lengths, svr_q.train_mse_r, label="random train mses", color="cyan")
plt.plot(svr_q.lengths, svr_q.val_mse_r, label="random val mses", color="magenta")
plt.vlines(m*0.7*0.9, 0, max(max(svr_q.train_mse_s), max(svr_q.val_mse_s), max(svr_q.train_mse_r), max(svr_q.val_mse_r)), linestyles="dotted", colors="black", label="interpolation boundary")
plt.vlines(svr_q.n_best_s, 0, max(max(svr_q.train_mse_s), max(svr_q.val_mse_s), max(svr_q.train_mse_r), max(svr_q.val_mse_r)), linestyles="dashed", colors="purple", label="SHRIMP best model")
plt.vlines(svr_q.n_best_r, 0, max(max(svr_q.train_mse_s), max(svr_q.val_mse_s), max(svr_q.train_mse_r), max(svr_q.val_mse_r)), linestyles="dashed", colors="orange", label="random best model")
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.semilogy(svr_q.lengths, svr_q.eigs_s_min, label="SHRIMP min eig", color="blue")
plt.semilogy(svr_q.lengths, svr_q.eigs_r_min, label="random min eig", color="orange")
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(svr_q.lengths, svr_q.eigs_s_max, label="SHRIMP max eig", color="blue")
plt.plot(svr_q.lengths, svr_q.eigs_r_max, label="random max eig", color="orange")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## krr

# %%
svr_d = shrimp_v_random(trials, Xtr, Ytr, Xte, Yte, d, N, l)

# %%
print("Min l2: {}".format(svr_d.err_l2))
print("SHRIMP: {}".format(svr_d.err_shrimp))
print("Random pruning: {}".format(svr_d.err_r))
# Out:
# Min l2: 0.016696401062429523
# SHRIMP: 0.010960344100196551
# Random pruning: 0.018448383362399387

# %%
plt.figure(figsize=(15, 10))
plt.plot(svr_d.lengths, svr_d.train_mse_s, label="SHRIMP train mses", color="blue")
plt.plot(svr_d.lengths, svr_d.val_mse_s, label="SHRIMP val mses", color="red")
plt.plot(svr_d.lengths, svr_d.train_mse_r, label="random train mses", color="cyan")
plt.plot(svr_d.lengths, svr_d.val_mse_r, label="random val mses", color="magenta")
plt.vlines(m*0.7*0.9, 0, max(max(svr_d.train_mse_s), max(svr_d.val_mse_s), max(svr_d.train_mse_r), max(svr_d.val_mse_r)), linestyles="dotted", colors="black", label="interpolation boundary")
plt.vlines(svr_d.n_best_s, 0, max(max(svr_d.train_mse_s), max(svr_d.val_mse_s), max(svr_d.train_mse_r), max(svr_d.val_mse_r)), linestyles="dashed", colors="purple", label="SHRIMP best model")
plt.vlines(svr_d.n_best_r, 0, max(max(svr_d.train_mse_s), max(svr_d.val_mse_s), max(svr_d.train_mse_r), max(svr_d.val_mse_r)), linestyles="dashed", colors="orange", label="random best model")
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.semilogy(svr_d.lengths, svr_d.eigs_s_min, label="SHRIMP min eig", color="blue")
plt.semilogy(svr_d.lengths, svr_d.eigs_r_min, label="random min eig", color="orange")
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(svr_d.lengths, svr_d.eigs_s_max, label="SHRIMP max eig", color="blue")
plt.plot(svr_d.lengths, svr_d.eigs_r_max, label="random max eig", color="orange")
plt.legend(loc="best")
plt.show()
