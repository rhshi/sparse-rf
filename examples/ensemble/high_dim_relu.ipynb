# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sparse_rf.algs.core import min_wl2, min_l2
from sparse_rf.modules import make_X, make_W, make_A
from sparse_rf.util import *
from sparse_rf.util.fns import *

# %%
m = 1000
d = 100
q = 2
active = relu

ratio_train = 0.7

# %%
X = make_X(d, m, dist=uniform)
X_train = X[:int(m*ratio_train), :]
X_test = X[int(m*ratio_train):, :]

# %%
y = (1+np.linalg.norm(X, axis=-1))**(-0.5)
y_train = y[:int(m*ratio_train)]
y_test = y[int(m*ratio_train):]

# %%
Ns = np.arange(1, 20201, 200)

# %%
results_dense = []
for N in Ns:
    res = []
    for _ in range(5):
        W = make_W(d, d, N=N)
        A_train = make_A(X_train, W, active=active)
        A_test = make_A(X_test, W, active=active)
        c = min_l2(A_train, y_train)
        res.append(np.linalg.norm(A_test@c - y_test) / len(y_test))
    results_dense.append(res)

# %%
results_sparse = []
for N in Ns:
    res = []
    for _ in range(5):
        W = make_W(d, q, N=N)
        A_train = make_A(X_train, W, active=active)
        A_test = make_A(X_test, W, active=active)
        c = min_l2(A_train, y_train)
        res.append(np.linalg.norm(A_test@c - y_test) / len(y_test))
    results_sparse.append(res)

# %%
print([np.mean(res) for res in results_dense])
plt.semilogy(Ns, [np.mean(res) for res in results_dense])
# Out:
# [0.018432232259446086, 0.002302152489635701, 0.0025020693227988866, 0.004208378796220349, 0.004401021894484524, 0.00287439909188618, 0.002436566886785113, 0.002161104314257387, 0.0020239751808498814, 0.001937959663862058, 0.0018114538764804182, 0.0018252602679622524, 0.00179721697725531, 0.0017626145551285037, 0.0017422571091539184, 0.001705541666041032, 0.0016869877057952153, 0.0016841460729826632, 0.001700955405317998, 0.0016734698437851918, 0.0016660407852461313, 0.0016236465039919524, 0.0016566850558047848, 0.0016467896722584564, 0.001588971657382179, 0.0016176488890647673, 0.0016089348862323345, 0.001583644319016319, 0.0016112620046968378, 0.0016019491779242251, 0.0015842328869846343, 0.0015898317206149422, 0.0016064893268637778, 0.0016136799539084282, 0.00158617334237695, 0.0015661284913158792, 0.0015623805655041484, 0.00155739555357757, 0.0015668438151653717, 0.00156665385323649, 0.0015436906325294198, 0.001553119547064988, 0.00157004481392666, 0.0015692942921885836, 0.0015489196938068995, 0.0015640702645534417, 0.0015491865142990013, 0.0015611361661570667, 0.001528377879471297, 0.0015537706285333169, 0.00154271886628575, 0.0015438846306859591, 0.0015503496172441288, 0.0015431794351032937, 0.0015606421091111959, 0.0015538577873223714, 0.0015488656024004689, 0.0015312126212104133, 0.0015523790753837017, 0.0015264628360169422, 0.0015259586325702165, 0.001524850139221645, 0.0015392454647973263, 0.0015256503822954702, 0.0015372119120924445, 0.0015363794248180727, 0.001538128613409206, 0.0015221553677742714, 0.0015128687042803442, 0.001535588083751181, 0.0015269784996871135, 0.00152334776234729, 0.0015332635368160712, 0.0015403588055956465, 0.0015374022945961387, 0.001529228763418395, 0.0015310930046207524, 0.0015313353600402472, 0.001532033882834822, 0.0015209685393215802, 0.0015303021836657509, 0.001523029882743887, 0.0015109679561359365, 0.0015257783126104423, 0.0015321044075217363, 0.0015202466919551232, 0.001521443236028403, 0.0015136506594832654, 0.0015041543449923916, 0.0014969766811044147, 0.0015261301891959188, 0.0015127512539414045, 0.0015264446951977547, 0.0015221756987633852, 0.0015125912852324362, 0.0015111693395848352, 0.0015194178208883231, 0.001521548854587888, 0.0015212089752873474, 0.001528213351418146, 0.0015173634021348893]

# %%
print([np.mean(res) for res in results_sparse])
plt.semilogy(Ns, [np.mean(res) for res in results_sparse])
# Out:
# [0.017670922735566537, 0.0024590561610413264, 0.0025352572066799526, 0.0043526023003580975, 0.005965659618039187, 0.0037185444423439447, 0.0031805117465743015, 0.0029868529244916715, 0.002832210446718233, 0.0026626895667980657, 0.002564192302000883, 0.002463061350862475, 0.0023228323953904655, 0.002408567007774123, 0.0022659797975451623, 0.0022679308558145738, 0.0022278550970691504, 0.0022517677860610713, 0.0021545675841288065, 0.002127957732680457, 0.0021448041724083803, 0.0021742969320900896, 0.0021246657154606963, 0.0021011369133198073, 0.002101844232965551, 0.002036222346185294, 0.002089436294971472, 0.002016521790996929, 0.0020127373170837322, 0.002027426559680595, 0.0020517608496502387, 0.002035212237911034, 0.0019976363855189394, 0.0020189860846137825, 0.0019794886911711227, 0.0019648022240444647, 0.002015022597992484, 0.0020128907816295495, 0.002003202856432704, 0.0019905861748641266, 0.001973740580098222, 0.001980895012975318, 0.0019296416639785741, 0.0020010135225282622, 0.0019137549950199097, 0.0019427184518121642, 0.0019744312863538608, 0.0019452303329592577, 0.0019627785485462654, 0.0019323057554305253, 0.001991373340661305, 0.0019250992587523251, 0.0019420466028961512, 0.0019025645806486405, 0.0019151483809455333, 0.0019363926298917907, 0.0018744725458923598, 0.0019322882470650226, 0.001929156544967957, 0.0019098532218484315, 0.0019104989508895135, 0.0019294210880089965, 0.0018738238800503249, 0.0019298333031695745, 0.0018942522536525563, 0.0018747389238491122, 0.0019039496064061571, 0.0018893000039116516, 0.0018988902678454278, 0.0019086800788543855, 0.0019034776304587887, 0.0019239561181434695, 0.0019083544030951967, 0.0018906618553844491, 0.0018818117972219078, 0.0018788649377612606, 0.0019312690619906765, 0.001878678631193166, 0.0018695449863991118, 0.0018944687320225418, 0.0019068904587748715, 0.0018652320993138474, 0.0018669990232250144, 0.0018846064769573515, 0.0018748187986327805, 0.0018870928864386002, 0.0018514177618101971, 0.0019030924424702292, 0.0018673195673537784, 0.0018844063775615761, 0.0018541001154508616, 0.001865946789066162, 0.0018771484788871798, 0.0018405159778778941, 0.0018615078787964894, 0.0018659441711979623, 0.0018936204412347453, 0.0018833199162480829, 0.0018702396564037934, 0.0018553323571402908, 0.0018738310562537255]

# %%
plt.semilogy(Ns, [np.mean(res) for res in results_dense], label="dense")
plt.semilogy(Ns, [np.mean(res) for res in results_sparse], label="sparse")
plt.xlabel("p")
plt.ylabel("test error")
plt.legend()
plt.show()
